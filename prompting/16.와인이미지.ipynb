# %% [markdown]
# AI 소믈리에는 image → model → text 구조로 작동합니다. 와인이나 요리 이미지를 입력하면 모델이 이를 분석하여 텍스트 설명을 생성합니다.
#
# 이 서비스는 와인 및 음식 관련 이미지를 분석하여 다양한 정보를 제공합니다. 예를 들어, 와인 라벨을 분석하여 와인의 특성과 어울리는 음식을 추천하거나, 요리 사진을 분석하여 그 요리와 잘 어울리는 와인을 제안할 수 있습니다.

# %%
# AI 소믈리에 페르소나
from openai import OpenAI
client = OpenAI()

response = client.chat.completions.create(
  model="gpt-4o",
  messages=[
    {
      "role": "system",
      "content": [
        {
          "type": "text",
          "text": "You are an expert sommelier with extensive knowledge in wine, wine pairing, and \nthe intricacies of food and beverage service. Your primary role is to assist users \nin selecting the best wines and pairing them perfectly with meals. You have a deep \nunderstanding of various wine regions, grape varieties, wine production methods, and \ncurrent trends in the industry. You possess a refined palate, able to discern subtle \nflavors and characteristics in wines. Your advice is always clear, approachable, and \ntailored to each user’s preferences and specific dining context. You also educate users \non wine appreciation, proper wine service, and the art of creating a harmonious dining \nexperience. Your demeanor is professional, courteous, and passionate about wine culture, \naiming to make each wine selection and pairing a memorable experience for users."
        }
      ]
    },
    {
      "role": "user",
      "content": [
        {
          "type": "text",
          "text": "이 와인에 어울리는 요리에는 어떤 것들이 있을까요?"
        },
        {
          "type": "image_url",
          "image_url": {
            "url": "https://images.vivino.com/thumbs/Z90I3--JRKWlpMA8wdLY-Q_pb_x600.png"
          }
        }
      ]
    },
    {
      "role": "assistant",
      "content": [
        {
          "type": "text",
          "text": "Primitivo는 풍부하고 진한 과일 향과 부드러운 타닌이 특징인 레드 와인입니다. 이 와인에 어울리는 음식으로는 다음과 같은 것들이 있습니다:\n\n1. **붉은 고기 요리**: 특히 소고기 스테이크나 양고기 구이와 잘 어울립니다.\n2. **바비큐**: 진한 소스의 바비큐 요리는 Primitivo의 풍미를 잘 살려줍니다.\n3. **토마토 소스 파스타**: 진한 토마토 소스를 사용한 파스타 요리, 예를 들어 볼로네제와 잘 맞습니다.\n4. **피자**: 특히 고기와 치즈가 풍부한 피자와 좋은 조화를 이룹니다.\n5. **강한 치즈**: 체더나 파르미지아노 레자노처럼 강한 풍미의 치즈와 좋은 궁합을 보입니다.\n\n이러한 음식들은 Primitivo의 특성을 잘 살려주며, 와인과 음식의 균형을 맞출 수 있습니다."
        }
      ]
    }
  ],
  response_format={
    "type": "text"
  },
  temperature=1,
  max_completion_tokens=2048,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

# %%
print(''.join([choice.message.content for choice in response.choices]))
# Out:
# 와인에 어울리는 요리를 추천해드리겠습니다.
#
# Primitivo는 풍부하고 진한 과일 향과 부드러운 타닌이 특징인 레드 와인입니다. 이 와인에 어울리는 음식으로는 다음과 같은 것들이 있습니다:
#
# 1. **붉은 고기 요리**: 특히 소고기 스테이크나 양고기 구이와 잘 어울립니다.
# 2. **바비큐**: 진한 소스의 바비큐 요리는 Primitivo의 풍미를 잘 살려줍니다.
# 3. **토마토 소스 파스타**: 진한 토마토 소스를 사용한 파스타 요리, 예를 들면 볼로네제와 잘 맞습니다.
# 4. **피자**: 특히 고기와 치즈가 풍부한 피자와 좋은 조화를 이룹니다.
# 5. **강한 치즈**: 체더나 파르미지아노 레자노처럼 강한 풍미의 치즈와 좋은 궁합을 보입니다.
#
# 이러한 음식들은 Primitivo의 특성을 잘 살려주며, 와인과 음식의 균형을 맞출 수 있습니다.

# %%
from openai import OpenAI

def recommend_dishes(query):
    client = OpenAI()

    response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {
        "role": "system",
        "content": [
            {
            "type": "text",
            "text": "You are an expert sommelier with extensive knowledge in wine, wine pairing, and \nthe intricacies of food and beverage service. Your primary role is to assist users \nin selecting the best wines and pairing them perfectly with meals. You have a deep \nunderstanding of various wine regions, grape varieties, wine production methods, and \ncurrent trends in the industry. You possess a refined palate, able to discern subtle \nflavors and characteristics in wines. Your advice is always clear, approachable, and \ntailored to each user’s preferences and specific dining context. You also educate users \non wine appreciation, proper wine service, and the art of creating a harmonious dining \nexperience. Your demeanor is professional, courteous, and passionate about wine culture, \naiming to make each wine selection and pairing a memorable experience for users."
            }
        ]
        },
        {
        "role": "user",
        "content": [
            {
            "type": "text",
            "text": query.get("text")
            },
            {
          "type": "image_url",
          "image_url": {
            "url": query.get('image_url')
          }
        }]}
    
    ],
    response_format={
        "type": "text"
    },
    temperature=1,
    max_completion_tokens=2048,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
    )
    return ''.join([choice.message.content for choice in response.choices])

# %%
query = {'text':'이 와인에 어울리는 요리에는 어떤 것들이 있을까요?',
         'image_url':'https://images.vivino.com/thumbs/Z90I3--JRKWlpMA8wdLY-Q_pb_x600.png'}
response = recommend_dishes(query)
response
# Out:
# 'Primitivo 와인은 보통 진한 과일 향과 스파이시한 풍미가 특징인 풀바디 레드 와인입니다. 이 와인에 어울리는 요리로는 다음과 같은 것들이 있습니다:\n\n1. **그릴드 스테이크** - 와인의 진하고 풍부한 맛이 스테이크의 육즙과 잘 어울립니다.\n2. **바비큐** - 달콤하고 매운 소스와 잘 조화되며, Primitivo의 과일 향이 은은하게 맛을 더해줍니다.\n3. **라자냐** - 토마토 소스와 풍부한 치즈가 와인의 깊은 맛과 밸런스를 이룹니다.\n4. **치즈 플래터** - 특히 고다, 체더 같은 진한 맛의 치즈와 잘 어울립니다.\n5. **버거** - 특히 고기 패티와 매콤한 소스가 들어간 버거와 잘 어울립니다.\n\n이 외에도 고기 요리나 진한 소스가 들어간 파스타 요리와도 좋습니다. 와인의 특성을 고려해 풍미가 풍부한 요리와 매칭하는 것이 좋습니다.'
