# %%
import pandas as pd

# %%
pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in c:\users\admin\miniconda3\envs\hipython\lib\site-packages (2.3.0)
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\admin\miniconda3\envs\hipython\lib\site-packages (from pandas) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\miniconda3\envs\hipython\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\miniconda3\envs\hipython\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\miniconda3\envs\hipython\lib\site-packages (from pandas) (2025.2)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: six>=1.5 in c:\users\admin\miniconda3\envs\hipython\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_excel("./data/datalab.xlsx")
df
# Out:
#      Unnamed: 0 Unnamed: 1  Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5
# 0           NaN        NaN         NaN        NaN         NaN        NaN
# 1           NaN        NaN         NaN        NaN         NaN        NaN
# 2           NaN        NaN         NaN        NaN         NaN        NaN
# 3           NaN        NaN         NaN        NaN         NaN        NaN
# 4           NaN        NaN         NaN        NaN         NaN        NaN
# ..          ...        ...         ...        ...         ...        ...
# 367  2025-07-10   34.66666  2025-07-10   13.33333  2025-07-10   13.33333
# 368  2025-07-11   45.33333  2025-07-11   25.33333  2025-07-11   13.33333
# 369  2025-07-12   34.66666  2025-07-12        8.0  2025-07-12    5.33333
# 370  2025-07-13   25.33333  2025-07-13   14.66666  2025-07-13    2.66666
# 371  2025-07-14   37.33333  2025-07-14       20.0  2025-07-14   10.66666
#
# [372 rows x 6 columns]

# %%
df = df[['Unnamed: 1','Unnamed: 3','Unnamed: 5']]

# %%
df1 = df.rename(columns={'Unnamed: 1':'스트레스'
                   ,'Unnamed: 3':'상담','Unnamed: 5':'챗봇'})

# %%
df1 = df1.iloc[6:]

# %%
df1
# Out:
#          스트레스        상담        챗봇
# 11       48.0  21.33333  14.66666
# 12   41.33333  13.33333      12.0
# 13   25.33333      12.0  13.33333
# 14       64.0  34.66666      16.0
# 15       48.0      20.0  25.33333
# ..        ...       ...       ...
# 367  34.66666  13.33333  13.33333
# 368  45.33333  25.33333  13.33333
# 369  34.66666       8.0   5.33333
# 370  25.33333  14.66666   2.66666
# 371  37.33333      20.0  10.66666
#
# [361 rows x 3 columns]

# %%
corr_matrix = df1.corr()
print(corr_matrix)
# Out:
#           스트레스        상담        챗봇
# 스트레스  1.000000  0.455012  0.310124
# 상담    0.455012  1.000000  0.326577
# 챗봇    0.310124  0.326577  1.000000

# %%
df3 = pd.read_excel("./data/datalab (6).xlsx")
df3
# Out:
#      Unnamed: 0 Unnamed: 1  Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5  \
# 0           NaN        NaN         NaN        NaN         NaN        NaN
# 1           NaN        NaN         NaN        NaN         NaN        NaN
# 2           NaN        NaN         NaN        NaN         NaN        NaN
# 3           NaN        NaN         NaN        NaN         NaN        NaN
# 4           NaN        NaN         NaN        NaN         NaN        NaN
# ..          ...        ...         ...        ...         ...        ...
# 367  2025-07-10   52.67379  2025-07-10   50.53475  2025-07-10   23.52941
# 368  2025-07-11   46.52406  2025-07-11       50.0  2025-07-11   24.59893
# 369  2025-07-12   40.10695  2025-07-12   23.79679  2025-07-12   14.97326
# 370  2025-07-13   39.57219  2025-07-13   25.93582  2025-07-13   13.63636
# 371  2025-07-14   51.06951  2025-07-14   63.90374  2025-07-14   25.93582
#
#      Unnamed: 6 Unnamed: 7
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# ..          ...        ...
# 367  2025-07-10   14.17112
# 368  2025-07-11   10.69518
# 369  2025-07-12   12.29946
# 370  2025-07-13   14.97326
# 371  2025-07-14   17.37967
#
# [372 rows x 8 columns]

# %%
df4 = df3[['Unnamed: 1','Unnamed: 3','Unnamed: 5','Unnamed: 7']]

# %%
df5 = df4.rename(columns={'Unnamed: 1':'스트레스'
                   ,'Unnamed: 3':'퇴사','Unnamed: 5':'상담','Unnamed: 7':'상사'})

# %%
df5 = df5.iloc[6:]

# %%
df5
# Out:
#          스트레스        퇴사        상담        상사
# 6    49.46524  39.57219  20.85561  51.06951
# 7    71.39037  88.50267   27.5401  47.86096
# 8    67.37967  88.23529  33.95721   48.6631
# 9    74.59893  79.41176  33.15508  48.93048
# 10    76.2032  85.02673   27.5401  46.52406
# ..        ...       ...       ...       ...
# 367  52.67379  50.53475  23.52941  14.17112
# 368  46.52406      50.0  24.59893  10.69518
# 369  40.10695  23.79679  14.97326  12.29946
# 370  39.57219  25.93582  13.63636  14.97326
# 371  51.06951  63.90374  25.93582  17.37967
#
# [366 rows x 4 columns]

# %%
corr_matrix = df5.corr()
print(corr_matrix)
# Out:
#           스트레스        퇴사        상담        상사
# 스트레스  1.000000  0.754629  0.771277  0.487902
# 퇴사    0.754629  1.000000  0.841539  0.467619
# 상담    0.771277  0.841539  1.000000  0.442069
# 상사    0.487902  0.467619  0.442069  1.000000

# %%
import matplotlib.pyplot as plt
plt.scatter(df5['스트레스'],df5['퇴사'])
plt.show()

# %% [markdown]
# # 상관관계 분석
# ## 피어슨 상관계수

# %%
import pandas as pd
from scipy.stats import pearsonr

# 키와 몸무게 간의 관계(일반적으로 키가 큰 사람이 몸무게도 더 나가는 경향이 있다.)
# 예시 데이터
data = {
    'height': [160, 165, 170, 175, 180],
    'weight': [50, 55, 65, 70, 80]
}
df = pd.DataFrame(data)

# 피어슨 상관계수 계산
corr, p_value = pearsonr(df['height'], df['weight'])

print(f"피어슨 상관계수: {corr:.2f}")
print(f"p-값: {p_value:.4f}")
# p값이 0.05유의수준보다 작으므로 귀무가설 기각, 일반적으로 키가크면 몸무게가 더 나간다.
# Out:
# 피어슨 상관계수: 0.99
# p-값: 0.0006

# %% [markdown]
# ## 스피어만 상관계수
#
# - 순위형 변수 간의 관계를 측정한다, 비선형 관계일 경우에도 사용이 가능하다.

# %%
import pandas as pd
from scipy.stats import spearmanr

# 학생 성적 순위와 스포츠 성적 순위 간의 관계
# 데이터프레임 구성
data = {
    'student': ['A', 'B', 'C', 'D', 'E'],
    'academic_rank': [1, 2, 3, 4, 5],
    'sports_rank': [4, 2, 1, 3, 5]
}
df = pd.DataFrame(data)

# 스피어만 상관계수 계산
rho, pval = spearmanr(df['academic_rank'], df['sports_rank'])

print(f"스피어만 상관계수: {rho:.3f}")
print(f"p-value: {pval:.4f}")
# p값이 0.05보다 크므로 귀무가설 체택: 학생순위와 스포츠 순위는 관계가 없다.
# Out:
# 스피어만 상관계수: 0.300
# p-value: 0.6238

# %% [markdown]
# ## 켄달의 타우
# - 변수의 순서 간의 상관성을 측정한다.
#
# - 순위 쌍 간의 일치와 불일치를 비교하여 상관관계를 계산한다.
# (작은 데이터셋에 적합한 방법)

# %%
import pandas as pd
from scipy.stats import kendalltau

# 사람 A~E의 키와 몸무게 순위
data = {
    'Person': ['A', 'B', 'C', 'D', 'E'],
    'Height_rank': [1, 2, 3, 4, 5],     # 키 순위
    'Weight_rank_1': [3, 4, 1, 2, 5],   # τ = 0.2
    'Weight_rank_2': [1, 2, 3, 4, 5],   # τ = 1
    'Weight_rank_3': [5, 4, 3, 2, 1]    # τ = -1
}

df = pd.DataFrame(data)

# 계수 계산
tau1, _ = kendalltau(df['Height_rank'], df['Weight_rank_1'])
tau2, _ = kendalltau(df['Height_rank'], df['Weight_rank_2'])
tau3, _ = kendalltau(df['Height_rank'], df['Weight_rank_3'])

print(f"상관계수 (Weight_rank_1): {tau1:.2f}")
print(f"상관계수 (Weight_rank_2): {tau2:.2f}")
print(f"상관계수 (Weight_rank_3): {tau3:.2f}")
# Out:
# 상관계수 (Weight_rank_1): 0.20
# 상관계수 (Weight_rank_2): 1.00
# 상관계수 (Weight_rank_3): -1.00
