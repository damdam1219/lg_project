# %% [markdown]
# IBDB 영화평 데이터 > 감성분류를 위한 트랜스포머 아키택쳐 모델 구축
#
# 1. 정수 토큰 시퀀스(길이 80)입력
#
# 2. 토큰 임베딩 + 위치 임베딩
#
# 3. 멀티 헤드 어텐션 (3head)
#
# 4. concate + 정규화
#
# 5. FFN (Dense + Dense)
#
# 6. concate + 정규화
#
# 7. 분류기 (Dense)

# %% [markdown]
# # 1. 정수 토큰 시퀀스(길이 80)입력

# %%
import tensorflow as tf
from tensorflow.keras import Model, layers

# %%
inputs = layers.Input(shape=(80, ))
input_embedding = layers.Embedding(input_dim = 1000, output_dim = 32)(inputs)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1757040717.474825   21728 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1916 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9

# %% [markdown]
# # 2. 토큰 임베딩 + 위치 임베딩

# %%
# 위치 임베딩
positions = tf.range(start = 0, limit = 80)
pos_embedding = layers.Embedding(input_dim = 80, output_dim = 32)(positions)
pos_enc_output = pos_embedding + input_embedding

# %% [markdown]
# 합치면, 모델은 **“어떤 단어가 어디에 있는지”**를 학습 가능

# %% [markdown]
# # 3. 멀티 헤드 어텐션 (3head)

# %%
attention_output = layers.MultiHeadAttention(num_heads = 3, key_dim = 32)(pos_enc_output,pos_enc_output)

# %% [markdown]
# 어텐션을 여러 번 동시에 수행해서, 모델이 입력 시퀀스의 다양한 관계와 패턴을 학습할 수 있도록한다.
# 약간 컨볼루샨의 필터같은 느낌.

# %% [markdown]
# 문장: “The cat sat on the mat”
#
# Head 1: “cat ↔ sat” 관계 집중 → 주어-동사 관계 파악
#
# Head 2: “cat ↔ mat” 관계 집중 → 장소 관계 파악
#
# Head 3: “sat ↔ mat” 관계 집중 → 동작-장소 관계 파악
#
# → 여러 헤드가 합쳐져 문장의 다양한 의미와 관계를 풍부하게 표현

# %% [markdown]
# # 4. concate + 정규화

# %%
x = layers.add([pos_enc_output, attention_output])
x = layers.BatchNormalization()(x)

# %% [markdown]
# 단어+위치 임베딩 합치면 값이 들쭉날쭉 → 모델이 어느 정보에 집중할지 헷갈림
#
# 정규화하면 값 범위를 일정하게 맞춰서, 멀티헤드 어텐션이 각 단어 관계를 정확하게 학습 가능

# %% [markdown]
# # 5. FFN (Dense + Dense)

# %% [markdown]
# # 6. concate + 정규화

# %%
from tensorflow.keras.models import Sequential
ffnn = Sequential([
    layers.Dense(64, activation = 'relu'),
    layers.Dense(32, activation ='relu')
    ])(x)
x = layers.add([ffnn, x])
x = layers.BatchNormalization()(x)

# %% [markdown]
# 어텐션/FFN 후 정규화 모두 같은 목적: 값 분포를 일정하게 유지해서 학습 안정화

# %% [markdown]
# # 7. 분류기 (Dense)

# %%
x = layers.GlobalAveragePooling1D()(x)
x = layers.Dropout(0.1)(x)
x = layers.Dense(64, activation = 'relu')(x)
x = layers.Dropout(0.1)(x)
outputs = layers.Dense(2, activation ='softmax')(x)

# %%
# 모델구성
model = Model(inputs = inputs, outputs= outputs)

# %%
model.compile(loss ='sparse_categorical_crossentropy'
              , optimizer = 'adam'
              , metrics = ['accuracy'])

# %%
# 데이터가지고오기
from tensorflow.keras.datasets import imdb
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words = 10000)

# %%
# 텍스트 데이터의 전처리
from tensorflow.keras.preprocessing.sequence import pad_sequences
# 영화평안의 사이즈를 맞추기 위해서 패딩을 사용
X_train_pad = pad_sequences(X_train, maxlen = 80, padding = 'post', truncating = 'post')
X_test_pad = pad_sequences(X_test, maxlen = 80, padding = 'post', truncating = 'post')

# %%
model.fit(X_train_pad, y_train, epochs = 10, batch_size = 200)
# Out:
# Epoch 1/10
# 2025-09-05 12:26:05.847238: I external/local_xla/xla/service/service.cc:163] XLA service 0x75a72c009170 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-09-05 12:26:05.847268: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9
# 2025-09-05 12:26:05.910896: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-09-05 12:26:06.229771: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91200
# 2025-09-05 12:26:06.414132: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-09-05 12:26:06.414299: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-09-05 12:26:06.414407: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-09-05 12:26:06.414496: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-09-05 12:26:06.414518: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-09-05 12:26:06.414555: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-09-05 12:26:06.414763: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-09-05 12:26:06.715363: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_28', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-09-05 12:26:07.247312: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1248', 200 bytes spill stores, 200 bytes spill loads
#
# 2025-09-05 12:26:07.371292: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1248', 36 bytes spill stores, 36 bytes spill loads
#
# 2025-09-05 12:26:07.416351: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_28', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-09-05 12:26:07.786951: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1555', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-09-05 12:26:08.007266: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_8', 304 bytes spill stores, 304 bytes spill loads
#
# 2025-09-05 12:26:08.479446: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1577', 128 bytes spill stores, 128 bytes spill loads
#
# 2025-09-05 12:26:08.709827: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_6', 424 bytes spill stores, 440 bytes spill loads
#
# 2025-09-05 12:26:09.121147: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_10', 104 bytes spill stores, 104 bytes spill loads
#
# 2025-09-05 12:26:09.308037: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1555', 552 bytes spill stores, 552 bytes spill loads
#   7/125 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.4988 - loss: 0.6945
# I0000 00:00:1757042773.867101   22960 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.7210 - loss: 0.5347
# Epoch 2/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7852 - loss: 0.4522
# Epoch 3/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7912 - loss: 0.4409
# Epoch 4/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7954 - loss: 0.4298
# Epoch 5/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8007 - loss: 0.4209
# Epoch 6/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8076 - loss: 0.4110
# Epoch 7/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8136 - loss: 0.3974
# Epoch 8/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8200 - loss: 0.3876
# Epoch 9/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8270 - loss: 0.3781
# Epoch 10/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8340 - loss: 0.3650

# %%
# 모델 평가하기
model.evaluate(X_test_pad, y_test)
# Out:
# 2025-09-05 12:27:40.001841: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-09-05 12:27:40.001893: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-09-05 12:27:40.001939: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-09-05 12:27:40.262044: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_9', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-09-05 12:27:40.764163: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_10', 84 bytes spill stores, 84 bytes spill loads
#
# 2025-09-05 12:27:40.914706: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_9', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-09-05 12:27:40.958541: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_10', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-09-05 12:27:41.006023: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_10', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-09-05 12:27:41.176293: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_6', 424 bytes spill stores, 440 bytes spill loads
# 767/782 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7701 - loss: 0.5301
# 2025-09-05 12:27:43.711206: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-09-05 12:27:43.711261: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-09-05 12:27:43.711305: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-09-05 12:27:43.932062: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_9', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-09-05 12:27:44.432873: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_10', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-09-05 12:27:44.523095: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_10', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-09-05 12:27:44.529897: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_6', 424 bytes spill stores, 440 bytes spill loads
#
# 2025-09-05 12:27:44.794253: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_9', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-09-05 12:27:44.844093: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_10', 84 bytes spill stores, 84 bytes spill loads
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.7669 - loss: 0.5346
# [0.5346301794052124, 0.7668799757957458]

# %%
import numpy as np
pred = model.predict(X_test_pad)
pred = np.argmax(pred, axis = 1)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, pred)
# Out:
# array([[ 9009,  3491],
#        [ 2337, 10163]])
