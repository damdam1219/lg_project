# %% [markdown]
# # 모델 구조 + 가중치

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
data_path = "datasets/data.yaml"

# %%
model.train(data=data_path ,epochs=3, imgsz=640)
# Out:
# Ultralytics 8.3.192  Python-3.10.18 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
result = model.predict('./1.png')
result
# Out:
# image 1/1 c:\Users\Admin\Desktop\dl_llm\1.png: 640x608 1 Paper, 1 Rock, 2 Scissorss, 25.0ms
# Speed: 4.0ms preprocess, 25.0ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 608)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Paper', 1: 'Rock', 2: 'Scissors'}
#  obb: None
#  orig_img: array([[[228, 227, 226],
#          [226, 222, 221],
#          [227, 224, 222],
#          ...,
#          [229, 230, 229],
#          [227, 225, 225],
#          [228, 226, 225]],
#
#         [[227, 225, 224],
#          [226, 220, 219],
#          [226, 222, 221],
#          ...,
#          [228, 229, 228],
#          [228, 227, 226],
#          [229, 228, 227]],
#
#         [[226, 221, 220],
#          [227, 224, 223],
#          [226, 222, 221],
#          ...,
#          [229, 229, 228],
#          [229, 229, 229],
#          [229, 229, 229]],
#
#         ...,
#
# ...

# %%
model = YOLO('runs\detect\train\weight\best.pt')
data_path = './datasets/data.yaml'
metrics = model.val(data =  data_path)
metrics
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 model = YOLO('runs\detect\train\weight\best.pt')
#       2 data_path = './datasets/data.yaml'
#       3 metrics = model.val(data =  data_path)
#
# File c:\Users\Admin\miniconda3\envs\torch_cuda_yolo_env\lib\site-packages\ultralytics\models\yolo\model.py:83, in YOLO.__init__(self, model, task, verbose)
#      80     self.__dict__ = new_instance.__dict__
#      81 else:
#      82     # Continue with default YOLO initialization
# ---> 83     super().__init__(model=model, task=task, verbose=verbose)
#      84     if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
#      85         from ultralytics import RTDETR
#
# ...

# %%
from ultralytics import YOLO

# best.pt 파일의 올바른 경로 지정 (weights로 수정)
model_path = 'runs/detect/train/weights/best.pt'
model = YOLO(model_path)

# 데이터셋 설정 파일 경로
data_path = './datasets/data.yaml'

# 모델 검증 및 지표 계산
metrics = model.val(data=data_path)

# 검증 결과 지표 출력
print(metrics)
# Out:
# Ultralytics 8.3.192  Python-3.10.18 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# Model summary (fused): 72 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 446.795.7 MB/s, size: 29.1 KB)
# val: Scanning C:\Users\Admin\Desktop\dl_llm\datasets\valid\labels.cache... 576 images, 238 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 576/576 576591.7it/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 36/36 11.0it/s 3.3s0.1s
#                    all        576        400      0.756      0.706      0.773      0.546
#                  Paper        132        139      0.731       0.54      0.633      0.425
#                   Rock        121        141      0.909      0.778      0.887      0.637
#               Scissors        116        120      0.627        0.8      0.798      0.577
# ...
